# %%
pip install requests beautifulsoup4 pandas
# Out:
# Requirement already satisfied: requests in c:\users\xx807\anaconda3\lib\site-packages (2.32.5)
# Requirement already satisfied: beautifulsoup4 in c:\users\xx807\anaconda3\lib\site-packages (4.13.5)
# Requirement already satisfied: pandas in c:\users\xx807\anaconda3\lib\site-packages (2.3.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\xx807\anaconda3\lib\site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\xx807\anaconda3\lib\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\xx807\anaconda3\lib\site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\xx807\anaconda3\lib\site-packages (from requests) (2026.1.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\xx807\anaconda3\lib\site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\xx807\anaconda3\lib\site-packages (from beautifulsoup4) (4.15.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\xx807\anaconda3\lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\xx807\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\xx807\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\xx807\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\xx807\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
"""
CISB5123 Text Analytics
Lab Assignment 1 - Web Scraping

Student Name: MOUSAB MOHAMMED ELHASSAN ADAM MOHAMMED 
Student ID: SW01084034

Platform: Trustpilot (Lenovo)
Pages scraped: 5
Output file: trustpilot_lenovo_reviews.csv
"""

import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

base_url = "https://www.trustpilot.com/review/www.lenovo.com?page={}"

headers = {
    "User-Agent": "Mozilla/5.0",
    "Accept-Language": "en-US,en;q=0.9"
}

reviews = []

def scrape_page(page_number):
    """
    This function downloads one Trustpilot review page
    and extracts:
    - reviewer name
    - review date
    - review content
    """
    url = base_url.format(page_number)
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, "html.parser")

    review_cards = soup.find_all("article")

    for card in review_cards:
        name_tag = card.find("span")
        date_tag = card.find("time")
        content_tag = card.find("p")

        if name_tag and date_tag and content_tag:
            reviewer_name = name_tag.get_text(strip=True)
            review_date = date_tag.get("datetime", "")[:10]
            review_content = content_tag.get_text(strip=True)

            reviews.append({
                "reviewer_name": reviewer_name,
                "review_date": review_date,
                "review_content": review_content
            })

# Scrape 5 pages
for page in range(1, 6):
    print(f"Scraping page {page}...")
    scrape_page(page)
    time.sleep(1)

# Save to CSV
df = pd.DataFrame(reviews)
df.to_csv("trustpilot_lenovo_reviews.csv", index=False, encoding="utf-8-sig")

print("Scraping completed.")
print("Total reviews collected:", len(df))
# Out:
# Scraping page 1...
# Scraping page 2...
# Scraping page 3...
# Scraping page 4...
# Scraping page 5...
# Scraping completed.
# Total reviews collected: 314
